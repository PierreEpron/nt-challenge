# %%
from bs4 import BeautifulSoup
from pathlib import Path
import requests
import re

# %%
URL = 'https://leconjugueur.lefigaro.fr/french/verb'

def is_bloc(tag):
    return tag.has_attr('class') and ('modeBloc' in tag.attrs['class'] or 'conjugBloc' in tag.attrs['class'])

class Verb:
    def __init__(self, inf, mode_temps, pronoms, freq, prefix='', suffix=''):
        self.inf = inf
        self.mode_temps = mode_temps
        self.pronoms = pronoms
        self.freq = freq
        self.prefix = prefix
        self.suffix = suffix
        self.data = {}
        self.scrap()
    
    def scrap(self):
        res = requests.get(f'{URL}/{self.inf}.html')
        soup = BeautifulSoup(res.text)
        mode = ''
        for tag in soup.find_all(is_bloc):
            if 'modeBloc' in tag.attrs['class']:
                mode = tag.text
            else:
                temps = tag.find('div', attrs={'class':'tempsBloc'})
                if temps:
                    text = list(tag.children)[1]
                    text = re.sub(r'<\/?(b|p)>', '', str(text))
                    self.data[f'{mode}_{temps.text}'] = text.split('<br/>')
 
    def is_valid(self, mode_temp, pronom, freq):
        return mode_temp in self.mode_temps and pronom in self.pronoms and freq == self.freq
    
    def get_text(self, mode_temp, pronom):
        return f'{self.prefix}{self.data[mode_temp][pronom]}{self.suffix}'

# %%
FREQUENCES = ['commun', 'rare']

MODE_TEMPS_FULL = ['Indicative_Present', 'Indicative_Imperfect', 'Conditional_Present', 'Conditional_First past']
MODE_TEMPS_PRESENT = ['Indicative_Present', 'Conditional_Present']
MODE_TEMPS_CONDITIONAL = ['Conditional_Present', 'Conditional_First past']

PRONOMS_FULL = [0, 2, 3, 5]

verbs = [
    Verb('demander', MODE_TEMPS_FULL, PRONOMS_FULL, 'commun', suffix=' à'),
    Verb('pouvoir', MODE_TEMPS_PRESENT, PRONOMS_FULL, 'commun'),
    Verb('vouloir', MODE_TEMPS_FULL, PRONOMS_FULL, 'commun'),
    Verb('desirer', MODE_TEMPS_FULL, PRONOMS_FULL, 'commun'),
    Verb('souhaiter', MODE_TEMPS_FULL, PRONOMS_FULL, 'commun'),
    Verb('aimer', MODE_TEMPS_CONDITIONAL, PRONOMS_FULL, 'commun'),
    Verb('exiger', MODE_TEMPS_FULL, PRONOMS_FULL, 'rare', suffix=' de'),
    Verb('rever', MODE_TEMPS_FULL, PRONOMS_FULL, 'rare', suffix=' de'),
    Verb('reclamer', MODE_TEMPS_FULL, PRONOMS_FULL, 'rare', suffix=' de'),
    Verb('esperer', MODE_TEMPS_FULL, PRONOMS_FULL, 'rare'),
    Verb('aspirer', MODE_TEMPS_FULL, PRONOMS_FULL, 'rare', suffix=' à'),
]

# %%
def get_block(prefix, verbs, mode_temp, pronom, freq):
    block = []
    for v in verbs:
        if v.is_valid(mode_temp, pronom, freq):
            block.append(v.get_text(mode_temp, pronom))
    return f'~[{prefix}_{mode_temp.lower()}_{pronom}_{freq}]\n    ' + '\n    '.join(block)
    
blocks = []

for mt in MODE_TEMPS_FULL:
    for p in PRONOMS_FULL:
        for f in FREQUENCES:
            blocks.append(get_block('vouloir', verbs, mt, p, f))

# %%
x1 = .70
x2 = .1 / (1-x1)
x3 = .1 / (1-x2) / (1-x1)
print(f'x1 : {x1*100}, x2 : {x2*100}, x3 : {x3*100}, p4 : {(1-x1) * (1-x2) * (1-x3) * 100}')
# Out:
# x1 : 70.0, x2 : 33.33333333333333, x3 : 49.999999999999986, p4 : 10.000000000000005

# %%
#########################
### PROBA MODE_TEMPS ####
#########################
# indicative_present : 55 
# indicative_imperfect : 10
# conditional_present : 25 
# conditional_first : 10
# x1 = .55 
# x2 = .1 / (1-x1) = .2222
# x3 = .25 / (1-x2) / (1-x1) = .7142
#########################
##### PROBA PRONOMS #####
#########################
# je (0) : 70
# il/elle (2) : 10
# nous (2) : 10
# ils/elles (2) : 10
# x1 = .70
# x2 = .1 / (1-x1) = .3333
# x3 = .1 / (1-x2) / (1-x1) = .4999
#########################
### PROBA FREQUENCES ####
#########################
# commun : 80
# rare : 20

PROBS = {
    'indicative_present' : '55',  
    'indicative_imperfect' : '22',
    'conditional_present' : '72',
    0 : '70', 
    2 : '33',
    3 : '50',
    'commun' : '80',
}

def generate_rules(k, arr):
    res = ''
    last_rule = (f'{k}_{arr[-1]}', len(arr)-1)
    for _ in range(len(arr)-1):
        if last_rule[1] == 1:
            current_rule = (k, last_rule[1] - 1)
        else:
            current_rule = (f'{k}-{last_rule[1]}', last_rule[1] - 1)
        s = arr[last_rule[1] - 1]
        p = PROBS[s]
        res += f'~[{current_rule[0]}]\n'
        res += f'    ~[{k}_{s}?{last_rule[1]}-{k}/{p}] ~[{last_rule[0]}?!{last_rule[1]}-{k}]\n\n'
        last_rule = current_rule
    return res.strip()

rules = []
rules.append(generate_rules(f'vouloir', [mt.lower() for mt in MODE_TEMPS_FULL]))        
for mt in MODE_TEMPS_FULL:
    rules.append(generate_rules(f'vouloir_{mt.lower()}', PRONOMS_FULL))        
    for p in PRONOMS_FULL:
        rules.append(generate_rules(f'vouloir_{mt.lower()}_{p}', FREQUENCES))

# %%
print(generate_rules('indicative_present', PRONOMS_FULL))
# Out:
# ~[indicative_present-3]
#     ~[indicative_present_3?3-indicative_present/50] ~[indicative_present_5?!3-indicative_present]
#
# ~[indicative_present-2]
#     ~[indicative_present_2?2-indicative_present/33] ~[indicative_present-3?!2-indicative_present]
#
# ~[indicative_present]
#     ~[indicative_present_0?1-indicative_present/70] ~[indicative_present-2?!1-indicative_present]

# %%
print(generate_rules('indicative_present_0', FREQUENCES))
# Out:
# ~[indicative_present_0]
#     ~[indicative_present_0_commun?1-indicative_present_0/80] ~[indicative_present_0_rare?!1-indicative_present_0]

# %%
print('\n\n'.join(blocks))
# Out:
# ~[vouloir_indicative_present_0_commun]
#     je demande à
#     je peux
#     je veux
#     je désire
#     je souhaite
#
# ~[vouloir_indicative_present_0_rare]
#     j'exige de
#     je rêve de
#     je réclame de
#     j'espère
#     j'aspire à
#
# ~[vouloir_indicative_present_2_commun]
#     il demande à
#     il peut
#     il veut
#     il désire
#     il souhaite
#
# ~[vouloir_indicative_present_2_rare]
#     il exige de
#     il rêve de
#     il réclame de
#     il espère
#     il aspire à
#
# ~[vouloir_indicative_present_3_commun]
#     nous demandons à
#     nous pouvons
#     nous voulons
#     nous désirons
#     nous souhaitons
#
# ~[vouloir_indicative_present_3_rare]
#     nous exigeons de
#     nous rêvons de
#     nous réclamons de
#     nous espérons
#     nous aspirons à
#
# ~[vouloir_indicative_present_5_commun]
#     ils demandent à
#     ils peuvent
#     ils veulent
#     ils désirent
#     ils souhaitent
#
# ~[vouloir_indicative_present_5_rare]
#     ils exigent de
#     ils rêvent de
#     ils réclament de
#     ils espèrent
#     ils aspirent à
#
# ~[vouloir_indicative_imperfect_0_commun]
#     je demandais à
#     je voulais
#     je désirais
#     je souhaitais
#
# ~[vouloir_indicative_imperfect_0_rare]
#     j'exigeais de
#     je rêvais de
#     je réclamais de
#     j'espérais
#     j'aspirais à
#
# ~[vouloir_indicative_imperfect_2_commun]
#     il demandait à
#     il voulait
#     il désirait
#     il souhaitait
#
# ~[vouloir_indicative_imperfect_2_rare]
#     il exigeait de
#     il rêvait de
#     il réclamait de
#     il espérait
#     il aspirait à
#
# ~[vouloir_indicative_imperfect_3_commun]
#     nous demandions à
#     nous voulions
#     nous désirions
#     nous souhaitions
#
# ~[vouloir_indicative_imperfect_3_rare]
#     nous exigions de
#     nous rêvions de
#     nous réclamions de
#     nous espérions
#     nous aspirions à
#
# ~[vouloir_indicative_imperfect_5_commun]
#     ils demandaient à
#     ils voulaient
#     ils désiraient
#     ils souhaitaient
#
# ~[vouloir_indicative_imperfect_5_rare]
#     ils exigeaient de
#     ils rêvaient de
#     ils réclamaient de
#     ils espéraient
#     ils aspiraient à
#
# ~[vouloir_conditional_present_0_commun]
#     je demanderais à
#     je pourrais
#     je voudrais
#     je désirerais
#     je souhaiterais
#     j'aimerais
#
# ~[vouloir_conditional_present_0_rare]
#     j'exigerais de
#     je rêverais de
#     je réclamerais de
#     j'espérerais
#     j'aspirerais à
#
# ~[vouloir_conditional_present_2_commun]
#     il demanderait à
#     il pourrait
#     il voudrait
#     il désirerait
#     il souhaiterait
#     il aimerait
#
# ~[vouloir_conditional_present_2_rare]
#     il exigerait de
#     il rêverait de
#     il réclamerait de
#     il espérerait
#     il aspirerait à
#
# ~[vouloir_conditional_present_3_commun]
#     nous demanderions à
#     nous pourrions
#     nous voudrions
#     nous désirerions
#     nous souhaiterions
#     nous aimerions
#
# ~[vouloir_conditional_present_3_rare]
#     nous exigerions de
#     nous rêverions de
#     nous réclamerions de
#     nous espérerions
#     nous aspirerions à
#
# ~[vouloir_conditional_present_5_commun]
#     ils demanderaient à
#     ils pourraient
#     ils voudraient
#     ils désireraient
#     ils souhaiteraient
#     ils aimeraient
#
# ~[vouloir_conditional_present_5_rare]
#     ils exigeraient de
#     ils rêveraient de
#     ils réclameraient de
#     ils espéreraient
#     ils aspireraient à
#
# ~[vouloir_conditional_first past_0_commun]
#     j'aurais demandé à
#     j'aurais voulu
#     j'aurais désiré
#     j'aurais souhaité
#     j'aurais aimé
#
# ~[vouloir_conditional_first past_0_rare]
#     j'aurais exigé de
#     j'aurais rêvé de
#     j'aurais réclamé de
#     j'aurais espéré
#     j'aurais aspiré à
#
# ~[vouloir_conditional_first past_2_commun]
#     il aurait demandé à
#     il aurait voulu
#     il aurait désiré
#     il aurait souhaité
#     il aurait aimé
#
# ~[vouloir_conditional_first past_2_rare]
#     il aurait exigé de
#     il aurait rêvé de
#     il aurait réclamé de
#     il aurait espéré
#     il aurait aspiré à
#
# ~[vouloir_conditional_first past_3_commun]
#     nous aurions demandé à
#     nous aurions voulu
#     nous aurions désiré
#     nous aurions souhaité
#     nous aurions aimé
#
# ~[vouloir_conditional_first past_3_rare]
#     nous aurions exigé de
#     nous aurions rêvé de
#     nous aurions réclamé de
#     nous aurions espéré
#     nous aurions aspiré à
#
# ~[vouloir_conditional_first past_5_commun]
#     ils auraient demandé à
#     ils auraient voulu
#     ils auraient désiré
#     ils auraient souhaité
#     ils auraient aimé
#
# ~[vouloir_conditional_first past_5_rare]
#     ils auraient exigé de
#     ils auraient rêvé de
#     ils auraient réclamé de
#     ils auraient espéré
#     ils auraient aspiré à

# %%
print('\n\n'.join(rules))
# Out:
# ~[vouloir-3]
#     ~[vouloir_conditional_present?3-vouloir/72] ~[vouloir_conditional_first past?!3-vouloir]
#
# ~[vouloir-2]
#     ~[vouloir_indicative_imperfect?2-vouloir/22] ~[vouloir-3?!2-vouloir]
#
# ~[vouloir]
#     ~[vouloir_indicative_present?1-vouloir/55] ~[vouloir-2?!1-vouloir]
#
# ~[vouloir_indicative_present-3]
#     ~[vouloir_indicative_present_3?3-vouloir_indicative_present/50] ~[vouloir_indicative_present_5?!3-vouloir_indicative_present]
#
# ~[vouloir_indicative_present-2]
#     ~[vouloir_indicative_present_2?2-vouloir_indicative_present/33] ~[vouloir_indicative_present-3?!2-vouloir_indicative_present]
#
# ~[vouloir_indicative_present]
#     ~[vouloir_indicative_present_0?1-vouloir_indicative_present/70] ~[vouloir_indicative_present-2?!1-vouloir_indicative_present]
#
# ~[vouloir_indicative_present_0]
#     ~[vouloir_indicative_present_0_commun?1-vouloir_indicative_present_0/80] ~[vouloir_indicative_present_0_rare?!1-vouloir_indicative_present_0]
#
# ~[vouloir_indicative_present_2]
#     ~[vouloir_indicative_present_2_commun?1-vouloir_indicative_present_2/80] ~[vouloir_indicative_present_2_rare?!1-vouloir_indicative_present_2]
#
# ~[vouloir_indicative_present_3]
#     ~[vouloir_indicative_present_3_commun?1-vouloir_indicative_present_3/80] ~[vouloir_indicative_present_3_rare?!1-vouloir_indicative_present_3]
#
# ~[vouloir_indicative_present_5]
#     ~[vouloir_indicative_present_5_commun?1-vouloir_indicative_present_5/80] ~[vouloir_indicative_present_5_rare?!1-vouloir_indicative_present_5]
#
# ~[vouloir_indicative_imperfect-3]
#     ~[vouloir_indicative_imperfect_3?3-vouloir_indicative_imperfect/50] ~[vouloir_indicative_imperfect_5?!3-vouloir_indicative_imperfect]
#
# ~[vouloir_indicative_imperfect-2]
#     ~[vouloir_indicative_imperfect_2?2-vouloir_indicative_imperfect/33] ~[vouloir_indicative_imperfect-3?!2-vouloir_indicative_imperfect]
#
# ~[vouloir_indicative_imperfect]
#     ~[vouloir_indicative_imperfect_0?1-vouloir_indicative_imperfect/70] ~[vouloir_indicative_imperfect-2?!1-vouloir_indicative_imperfect]
#
# ~[vouloir_indicative_imperfect_0]
#     ~[vouloir_indicative_imperfect_0_commun?1-vouloir_indicative_imperfect_0/80] ~[vouloir_indicative_imperfect_0_rare?!1-vouloir_indicative_imperfect_0]
#
# ~[vouloir_indicative_imperfect_2]
#     ~[vouloir_indicative_imperfect_2_commun?1-vouloir_indicative_imperfect_2/80] ~[vouloir_indicative_imperfect_2_rare?!1-vouloir_indicative_imperfect_2]
#
# ~[vouloir_indicative_imperfect_3]
#     ~[vouloir_indicative_imperfect_3_commun?1-vouloir_indicative_imperfect_3/80] ~[vouloir_indicative_imperfect_3_rare?!1-vouloir_indicative_imperfect_3]
#
# ~[vouloir_indicative_imperfect_5]
#     ~[vouloir_indicative_imperfect_5_commun?1-vouloir_indicative_imperfect_5/80] ~[vouloir_indicative_imperfect_5_rare?!1-vouloir_indicative_imperfect_5]
#
# ~[vouloir_conditional_present-3]
#     ~[vouloir_conditional_present_3?3-vouloir_conditional_present/50] ~[vouloir_conditional_present_5?!3-vouloir_conditional_present]
#
# ~[vouloir_conditional_present-2]
#     ~[vouloir_conditional_present_2?2-vouloir_conditional_present/33] ~[vouloir_conditional_present-3?!2-vouloir_conditional_present]
#
# ~[vouloir_conditional_present]
#     ~[vouloir_conditional_present_0?1-vouloir_conditional_present/70] ~[vouloir_conditional_present-2?!1-vouloir_conditional_present]
#
# ~[vouloir_conditional_present_0]
#     ~[vouloir_conditional_present_0_commun?1-vouloir_conditional_present_0/80] ~[vouloir_conditional_present_0_rare?!1-vouloir_conditional_present_0]
#
# ~[vouloir_conditional_present_2]
#     ~[vouloir_conditional_present_2_commun?1-vouloir_conditional_present_2/80] ~[vouloir_conditional_present_2_rare?!1-vouloir_conditional_present_2]
#
# ~[vouloir_conditional_present_3]
#     ~[vouloir_conditional_present_3_commun?1-vouloir_conditional_present_3/80] ~[vouloir_conditional_present_3_rare?!1-vouloir_conditional_present_3]
#
# ~[vouloir_conditional_present_5]
#     ~[vouloir_conditional_present_5_commun?1-vouloir_conditional_present_5/80] ~[vouloir_conditional_present_5_rare?!1-vouloir_conditional_present_5]
#
# ~[vouloir_conditional_first past-3]
#     ~[vouloir_conditional_first past_3?3-vouloir_conditional_first past/50] ~[vouloir_conditional_first past_5?!3-vouloir_conditional_first past]
#
# ~[vouloir_conditional_first past-2]
#     ~[vouloir_conditional_first past_2?2-vouloir_conditional_first past/33] ~[vouloir_conditional_first past-3?!2-vouloir_conditional_first past]
#
# ~[vouloir_conditional_first past]
#     ~[vouloir_conditional_first past_0?1-vouloir_conditional_first past/70] ~[vouloir_conditional_first past-2?!1-vouloir_conditional_first past]
#
# ~[vouloir_conditional_first past_0]
#     ~[vouloir_conditional_first past_0_commun?1-vouloir_conditional_first past_0/80] ~[vouloir_conditional_first past_0_rare?!1-vouloir_conditional_first past_0]
#
# ~[vouloir_conditional_first past_2]
#     ~[vouloir_conditional_first past_2_commun?1-vouloir_conditional_first past_2/80] ~[vouloir_conditional_first past_2_rare?!1-vouloir_conditional_first past_2]
#
# ~[vouloir_conditional_first past_3]
#     ~[vouloir_conditional_first past_3_commun?1-vouloir_conditional_first past_3/80] ~[vouloir_conditional_first past_3_rare?!1-vouloir_conditional_first past_3]
#
# ~[vouloir_conditional_first past_5]
#     ~[vouloir_conditional_first past_5_commun?1-vouloir_conditional_first past_5/80] ~[vouloir_conditional_first past_5_rare?!1-vouloir_conditional_first past_5]

# %%
Path('chatette/verbs.chatette').write_text('\n\n'.join(rules+blocks), encoding='utf-8')
# Out:
# 9810

# %%
import pandas as pd
from slugify import slugify

# %%
entities = pd.read_csv('.data/entities.csv')
doctors = entities[entities['type'] == 'doctor']['label'].values
services = entities[entities['type'] == 'service']['label'].values

# %%
def indent(value, space_count=4):
    return (' ' * space_count) + value

def block(value):
    return f'~[{value}]'

def entry(value, train_size, test_size):
    return f"%[{value}]('train': '{train_size}', 'test': '{test_size}')"
    
def entity(value, label, role=''):
    if role == '':
        return f'\[{value}\]({label})'
    return f'\[{value}\]' + '\{' + f'"entity": "{label}", "role": "{role}"' + '\}'

# %%
def contact_doctor(doctor, train_size, test_size):
    lines = []
    slug = slugify(doctor).replace('-', '_')
    lines.append(entry(f'contact_doctor_{slug}', train_size, test_size))
    lines += contact_doctor_content(doctor)
    return lines

def contact_doctor_content(doctor):
    lines = []
    lastname = doctor.split()[0]
    lines.append(indent(block(f'contact doctor simple${entity(doctor, "doctor", "target")}')))
    lines.append(indent(block(f'contact doctor simple${entity(lastname, "doctor", "target")}')))
    lines.append(indent(block(f'contact doctor medium${entity(doctor, "doctor", "target")}')))
    lines.append(indent(block(f'contact doctor medium${entity(lastname, "doctor", "target")}')))
    return lines
    
def contact_service(service, train_size, test_size):
    lines = []
    slug = slugify(service).replace('-', '_')
    lines.append(entry(f'contact_service_{slug}', train_size, test_size))
    lines += contact_service_content(service)
    return lines
    
def contact_service_content(service):
    lines = []
    lines.append(indent(block(f'contact service simple${entity(service, "service", "target")}')))
    lines.append(indent(block(f'contact service medium${entity(service, "service", "target")}')))
    return lines

# %%
TRAIN_SIZE = 50
TEST_SIZE = 15
UNKOWN_TRAIN_SIZE = 200
UNKOWN_TEST_SIZE = 50
UNKOWN_SERVICE = ['lune', 'soleil', 'Paris', 'gouvernement', 'tour effeil', 'paradis', 'perpet les alouettes',
                 'clinique', 'hopital', 'charité', 'église', 'mer', 'caserne', 'restaurant', 'magasins', 'coiffeur', 'pizzeria',
                 'cabinet']
UNKOWN_DOCTOR = ['PRINCE Aladdin', 'EPRON Pierre', 'VALJEAN Jean', 'MACRON Emmanuel', 'DIEU Vivant', 'CHRIST Jesus', 'ZIDANE Zinedine',
                'CASTEX Jean', 'DUPONT philipe', 'CHRISTIE Agatha', 'D\'Arc Jeanne', 'SALDANA Ione', 'DANOURA Kobushi', 'WALKER helene', 
                 'HAMPTON Kelsie', 'CURRY Marie']

lines = []
for doctor in doctors:
    lines += contact_doctor(doctor, TRAIN_SIZE, TEST_SIZE)
    lines.append('\n')

for service in services:
    lines += contact_service(service, TRAIN_SIZE, TEST_SIZE)
    lines.append('\n')

    
lines.append(entry('contact_doctor_unknown', UNKOWN_TRAIN_SIZE, UNKOWN_TEST_SIZE))
for doctor in UNKOWN_DOCTOR:
    lines += contact_doctor_content(doctor)
lines.append('\n')

lines.append(entry('contact_service_unknown', UNKOWN_TRAIN_SIZE, UNKOWN_TEST_SIZE))
for service in UNKOWN_SERVICE:
    lines += contact_service_content(service)
lines.append('\n')

lines.append(entry('out_of_scope', UNKOWN_TRAIN_SIZE, UNKOWN_TEST_SIZE))
lines.append(indent(block('start noise')))
lines.append(indent(block('problems')))
lines.append(indent(block('from doctor')))
lines.append(indent(block('end noise')))
lines.append(indent(block('random')))
lines.append('\n')

    
lines.append('|doctors.chatette')
lines.append('|services.chatette')
lines.append('|noises.chatette')
lines.append('|verbs.chatette')
lines.append('|others.chatette')
    
print('\n'.join(lines))    
Path('chatette/main.chatette').write_text('\n'.join(lines), encoding='utf-8')
# Out:
# %[contact_doctor_aboab_jennifer]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ABOAB Jennifer\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ABOAB\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ABOAB Jennifer\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ABOAB\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_aboucaya_jean_paul]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ABOUCAYA Jean-Paul\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ABOUCAYA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ABOUCAYA Jean-Paul\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ABOUCAYA\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_al_moussarih_abdallah]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[AL MOUSSARIH Abdallah\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[AL\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[AL MOUSSARIH Abdallah\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[AL\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_allard_anne]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ALLARD Anne\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ALLARD\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ALLARD Anne\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ALLARD\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_alonso_enrique]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ALONSO Enrique\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ALONSO\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ALONSO Enrique\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ALONSO\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_aptecar_eduardo]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[APTECAR Eduardo\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[APTECAR\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[APTECAR Eduardo\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[APTECAR\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_aristizabal_patrick]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ARISTIZABAL Patrick\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ARISTIZABAL\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ARISTIZABAL Patrick\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ARISTIZABAL\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_armandon_denis]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[ARMANDON Denis\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ARMANDON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ARMANDON Denis\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ARMANDON\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bado_fabrice]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BADO Fabrice\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BADO\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BADO Fabrice\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BADO\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bauer_bertrand]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BAUER Bertrand\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BAUER\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BAUER Bertrand\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BAUER\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_becherel_pierre_andre]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BECHEREL Pierre-André\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BECHEREL\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BECHEREL Pierre-André\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BECHEREL\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_belda_eric]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BELDA Eric\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BELDA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELDA Eric\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELDA\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_belhassen_laurent]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BELHASSEN Laurent\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BELHASSEN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELHASSEN Laurent\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELHASSEN\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_belmaghni_fatma]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BELMAGHNI Fatma\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BELMAGHNI\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELMAGHNI Fatma\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BELMAGHNI\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_benhamou_claude]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BENHAMOU Claude\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BENHAMOU\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENHAMOU Claude\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENHAMOU\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_benosman_hedi]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BENOSMAN Hedi\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BENOSMAN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENOSMAN Hedi\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENOSMAN\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_benouaiche_laurence]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BENOUAICHE Laurence\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BENOUAICHE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENOUAICHE Laurence\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENOUAICHE\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bensaid_cherazade]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BENSAID Cherazade\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BENSAID\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENSAID Cherazade\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BENSAID\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_blavier_benedicte]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BLAVIER Bénédicte\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BLAVIER\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BLAVIER Bénédicte\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BLAVIER\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_blin_jean_louis]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BLIN Jean-Louis\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BLIN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BLIN Jean-Louis\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BLIN\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_borie_herve]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BORIE Hervé\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BORIE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BORIE Hervé\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BORIE\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bossi_philippe]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BOSSI Philippe\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BOSSI\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOSSI Philippe\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOSSI\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bouchareb_adam]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BOUCHAREB Adam\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BOUCHAREB\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOUCHAREB Adam\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOUCHAREB\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_boulet_stephane]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BOULET Stéphane\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BOULET\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOULET Stéphane\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BOULET\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_brun_magali]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BRUN Magali\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BRUN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUN Magali\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUN\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_brun_laurent]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BRUN Laurent\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BRUN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUN Laurent\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUN\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_brunet_morgan]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BRUNET Morgan\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BRUNET\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUNET Morgan\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUNET\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_brunet_oceane]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BRUNET Océane\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BRUNET\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUNET Océane\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRUNET\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_bryon_dominique]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[BRYON Dominique\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[BRYON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRYON Dominique\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[BRYON\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_doctor_cadot_bernard]('train': '50', 'test': '15')
#     ~[contact doctor simple$\[CADOT Bernard\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CADOT\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CADOT Bernard\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CADOT\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_service_gastro_enterologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Gastro-entérologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Gastro-entérologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_angiologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Angiologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Angiologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_ophtalmologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Ophtalmologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Ophtalmologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_orl]('train': '50', 'test': '15')
#     ~[contact service simple$\[ORL\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[ORL\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_accueil]('train': '50', 'test': '15')
#     ~[contact service simple$\[Accueil\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Accueil\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_admissions]('train': '50', 'test': '15')
#     ~[contact service simple$\[Admissions\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Admissions\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_soins_ambulatoire]('train': '50', 'test': '15')
#     ~[contact service simple$\[Soins ambulatoire\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Soins ambulatoire\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_planification]('train': '50', 'test': '15')
#     ~[contact service simple$\[Planification\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Planification\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_urgence]('train': '50', 'test': '15')
#     ~[contact service simple$\[Urgence\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Urgence\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_anesthesie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Anesthésie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Anesthésie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_unite_de_soins_continus]('train': '50', 'test': '15')
#     ~[contact service simple$\[Unité de Soins continus\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Unité de Soins continus\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_angiographie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Angiographie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Angiographie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_stomatologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Stomatologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Stomatologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_stomatherapie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Stomathérapie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Stomathérapie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_assistante_hoteliere]('train': '50', 'test': '15')
#     ~[contact service simple$\[Assistante hôtelière\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Assistante hôtelière\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_sophrologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Sophrologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Sophrologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_assistante_logistique]('train': '50', 'test': '15')
#     ~[contact service simple$\[Assistante logistique\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Assistante logistique\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_oncologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Oncologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Oncologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_assistante_sociale]('train': '50', 'test': '15')
#     ~[contact service simple$\[Assistante sociale\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Assistante sociale\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_biomedical]('train': '50', 'test': '15')
#     ~[contact service simple$\[Biomédical\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Biomédical\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_chirurgie_de_la_main]('train': '50', 'test': '15')
#     ~[contact service simple$\[Chirurgie de la main\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Chirurgie de la main\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_scintigraphie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Scintigraphie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Scintigraphie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_rythmologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Rythmologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Rythmologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_rhumatologie]('train': '50', 'test': '15')
#     ~[contact service simple$\[rhumatologie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[rhumatologie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_ressources_humaines]('train': '50', 'test': '15')
#     ~[contact service simple$\[Ressources Humaines\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Ressources Humaines\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_chirurgie_vasculaire]('train': '50', 'test': '15')
#     ~[contact service simple$\[Chirurgie vasculaire\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Chirurgie vasculaire\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_chirurgie_viscerale]('train': '50', 'test': '15')
#     ~[contact service simple$\[Chirurgie Viscérale\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Chirurgie Viscérale\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_pediatrie]('train': '50', 'test': '15')
#     ~[contact service simple$\[Pédiatrie\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Pédiatrie\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_chirurgie_digestive]('train': '50', 'test': '15')
#     ~[contact service simple$\[Chirurgie digestive\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Chirurgie digestive\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_service_chirurgie_orthopedique]('train': '50', 'test': '15')
#     ~[contact service simple$\[Chirurgie orthopédique\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Chirurgie orthopédique\]\{"entity": "service", "role": "target"\}]
#
#
# %[contact_doctor_unknown]('train': '200', 'test': '50')
#     ~[contact doctor simple$\[PRINCE Aladdin\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[PRINCE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[PRINCE Aladdin\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[PRINCE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[EPRON Pierre\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[EPRON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[EPRON Pierre\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[EPRON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[VALJEAN Jean\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[VALJEAN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[VALJEAN Jean\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[VALJEAN\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[MACRON Emmanuel\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[MACRON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[MACRON Emmanuel\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[MACRON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DIEU Vivant\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DIEU\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DIEU Vivant\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DIEU\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CHRIST Jesus\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CHRIST\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CHRIST Jesus\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CHRIST\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ZIDANE Zinedine\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[ZIDANE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ZIDANE Zinedine\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[ZIDANE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CASTEX Jean\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CASTEX\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CASTEX Jean\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CASTEX\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DUPONT philipe\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DUPONT\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DUPONT philipe\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DUPONT\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CHRISTIE Agatha\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CHRISTIE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CHRISTIE Agatha\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CHRISTIE\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[D'Arc Jeanne\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[D'Arc\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[D'Arc Jeanne\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[D'Arc\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[SALDANA Ione\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[SALDANA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[SALDANA Ione\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[SALDANA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DANOURA Kobushi\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[DANOURA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DANOURA Kobushi\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[DANOURA\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[WALKER helene\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[WALKER\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[WALKER helene\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[WALKER\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[HAMPTON Kelsie\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[HAMPTON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[HAMPTON Kelsie\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[HAMPTON\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CURRY Marie\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor simple$\[CURRY\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CURRY Marie\]\{"entity": "doctor", "role": "target"\}]
#     ~[contact doctor medium$\[CURRY\]\{"entity": "doctor", "role": "target"\}]
#
#
# %[contact_service_unknown]('train': '200', 'test': '50')
#     ~[contact service simple$\[lune\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[lune\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[soleil\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[soleil\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[Paris\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[Paris\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[gouvernement\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[gouvernement\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[tour effeil\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[tour effeil\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[paradis\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[paradis\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[perpet les alouettes\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[perpet les alouettes\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[clinique\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[clinique\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[hopital\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[hopital\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[charité\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[charité\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[église\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[église\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[mer\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[mer\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[caserne\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[caserne\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[restaurant\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[restaurant\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[magasins\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[magasins\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[coiffeur\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[coiffeur\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[pizzeria\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[pizzeria\]\{"entity": "service", "role": "target"\}]
#     ~[contact service simple$\[cabinet\]\{"entity": "service", "role": "target"\}]
#     ~[contact service medium$\[cabinet\]\{"entity": "service", "role": "target"\}]
#
#
# %[out_of_scope]('train': '200', 'test': '50')
#     ~[start noise]
#     ~[problems]
#     ~[from doctor]
#     ~[end noise]
#     ~[random]
#
#
# |doctors.chatette
# |services.chatette
# |noises.chatette
# |verbs.chatette
# |others.chatette
# 28149

# %%
from rasa.shared.nlu.training_data.formats.rasa_yaml import RasaYAMLReader
from rasa.shared.nlu.training_data.message import Message
from rasa.shared.nlu.training_data.entities_parser import parse_training_example
import json

# %%
def correct_encoding(text):
    chars = [
        ('\xc3\xaa', 'ê'), # 0
        ('\xc3\xa9', 'é'), # 1
        ('\xc3\xa8', 'è'), # 2
        ('\xc3\xab', 'ë'), # 3
        ('\xc3\xa2', 'â'), # 5
        ('\xc3\xa4', 'ä'), # 6
        ('\xc3\xb4', 'ô'), # 7
        ('\xc3\xb6', 'ö'), # 8
        ('\xc3\xae', 'î'), # 9
        ('\xc3\xaf', 'ï'), # 10
        ('\xc3\xbb', 'û'), # 11
        ('\xc3\xbc', 'ü'), # 12
        ('\xc3\xb9', 'ù'), # 13
        ('\xc3', 'à'),     # 4
    ]
    for i, j in chars:
        text = text.replace(i, j)
    return text

# %%
#### path = Path('output/train/output.json')

def load_from_chatette(path):
    examples = json.loads(correct_encoding(path.read_text()))
    data = RasaYAMLReader().reads(Path('.data/nlu_rs_base.yml').read_text('utf-8'))
    data.training_examples.clear()

    for item in examples['rasa_nlu_data']['common_examples']:
        if 'contact_doctor_' in item['intent']:
            item['intent'] = item['intent'].replace('contact_doctor_', 'contact_doctor/')
        if 'contact_service_' in item['intent']:
            item['intent'] = item['intent'].replace('contact_service_', 'contact_service/')
        data.training_examples.append(parse_training_example(item['text'], item['intent']))

    for doctor in doctors:
        slug = slugify(doctor).replace('-', '_')
        data.responses.update({f'utter_contact_doctor/{slug}': [{'text': f'Bonjour, j\'ai compris que vous cherchiez à contacter le docteur {doctor}'}]})

    for service in services:
        slug = slugify(service).replace('-', '_')
        data.responses.update({f'utter_contact_service/{slug}': [{'text': f'Bonjour, j\'ai compris que vous cherchiez à contacter le service {service}'}]})

    data.responses.update({f'utter_contact_doctor/unknown': [{'text': f'Bonjour, j\'ai compris que vous cherchiez à contacter un docteur. Je n\'ai pas compris lequel'}]})
    data.responses.update({f'utter_contact_service/unknown': [{'text': f'Bonjour, j\'ai compris que vous cherchiez à contacter un service. Je n\'ai pas compris lequel'}]})
    data.responses.update({f'utter_out_of_scope': [{'text': f'Bonjour, je ne suis pas entrainé a répondre à votre demande !'}]})
    return data

# %%
data = load_from_chatette(Path('output/train/output.json'))
data.persist('data')
# Out:
# C:\Users\pierr\Documents\projets\nt-challenge\venv\lib\site-packages\rasa\shared\utils\io.py:99: UserWarning: Training data file  has a lower format version than your Rasa Open Source installation: 3.0 < 3.1. Rasa Open Source will read the file as a version 3.1 file. Please update your version key to 3.1. See https://rasa.com/docs/rasa/training-data-format.
# {'training_data': 'training_data.yml'}

# %%
data = load_from_chatette(Path('output/test/output.json'))
data.persist('tests')
# Out:
# {'training_data': 'training_data.yml'}
